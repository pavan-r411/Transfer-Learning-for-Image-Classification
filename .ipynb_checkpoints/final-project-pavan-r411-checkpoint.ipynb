# %%
import os
import random
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
import cv2
from tensorflow.keras.applications import ResNet50, ResNet101, VGG16, EfficientNetB0
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization, Input
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers.schedules import CosineDecayRestarts

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %% [markdown]
# <b>1. Transfer Learning for Image Classification
# It is highly recommended that you complete this project using Keras1 and Python.<br>
# (a) In this problem, we are trying to build a classifier that distinguishes images of
# nine types of waste.<br>
# (b) Data Exploration and Pre-processing<br>
# i. Images are numbered in each folder. Select the first 80% of the images in
# each folder as your training set and the rest as the test set. You can encode
# your classes using one-hot encoding.<br>
# ii. In case all the images do not have the same size, zero-pad or resize the images
# in your dataset. This can be done using various tools, including OpenCV.</b>

# %%
# Global dictionary to store metrics for each model
model_results = {}

# %%
# --- Configuration ---
DATASET_PATH = "../PDFProject/RealWaste/" 
IMG_SIZE = (224, 224)
SEED = 42

# --- Prepare ---
random.seed(SEED)
class_names = sorted(os.listdir(DATASET_PATH))
num_classes = len(class_names)

X_train, y_train = [], []
X_test, y_test = [], []

for class_idx, class_name in enumerate(class_names):
    class_dir = os.path.join(DATASET_PATH, class_name)
    if not os.path.isdir(class_dir):
        continue

    images = sorted(os.listdir(class_dir))
    total = len(images)
    train_count = int(0.8 * total)
    
    train_files = images[:train_count]
    test_files = images[train_count:]

    def load_images(file_list):
        data = []
        for file in file_list:
            path = os.path.join(class_dir, file)
            img = cv2.imread(path)
            if img is not None:
                img = cv2.resize(img, IMG_SIZE)
                data.append(img)
        return data

    X_train.extend(load_images(train_files))
    y_train.extend([class_idx] * len(train_files))

    X_test.extend(load_images(test_files))
    y_test.extend([class_idx] * len(test_files))

X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

print(" Done!")
print("X_train:", X_train.shape, "y_train:", y_train.shape)
print("X_test:", X_test.shape, "y_test:", y_test.shape)
# Out:
#  Done!
# X_train: (3798, 224, 224, 3) y_train: (3798, 9)
# X_test: (954, 224, 224, 3) y_test: (954, 9)

# %%
def initialise_transfer_model(base_model_name: str, input_shape=(224, 224, 3), num_classes=9):
    match base_model_name.lower():
        case "resnet50":
            base_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)
        case "resnet101":
            base_model = ResNet101(weights='imagenet', include_top=False, input_shape=input_shape)
        case "vgg16":
            base_model = VGG16(weights='imagenet', include_top=False, input_shape=input_shape)
        case "efficientnetb0":
            base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=input_shape)
        case _:
            raise ValueError(f"Unknown model name: {base_model_name}")

    base_model.trainable = False

    inputs = Input(shape=input_shape)
    x = base_model(inputs, training=False)
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    x = Dense(256, activation='relu', kernel_regularizer=l2(0.01))(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    return Model(inputs, outputs)

# %%
def evaluate_metrics(y_true, y_pred):
    y_true_cls = np.argmax(y_true, axis=1)
    y_pred_cls = np.argmax(y_pred, axis=1)
    precision = precision_score(y_true_cls, y_pred_cls, average='macro')
    recall = recall_score(y_true_cls, y_pred_cls, average='macro')
    f1 = f1_score(y_true_cls, y_pred_cls, average='macro')
    try:
        auc = roc_auc_score(y_true, y_pred, multi_class='ovo', average='macro')
    except:
        auc = None
    return precision, recall, f1, auc

# %%
class DelayedEarlyStopping(tf.keras.callbacks.EarlyStopping):
    def __init__(self, min_epochs=50, **kwargs):
        super().__init__(**kwargs)
        self.min_epochs = min_epochs

    def on_epoch_end(self, epoch, logs=None):
        if epoch + 1 >= self.min_epochs:
            super().on_epoch_end(epoch, logs)


def run_transfer_learning_pipeline(base_model_fn, X_train, y_train, X_val, y_val, X_test, y_test, batch_size=32, epochs=100):
    model = initialise_transfer_model(base_model_fn, input_shape=X_train.shape[1:], num_classes=y_train.shape[1])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    early_stop = DelayedEarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, min_epochs=50)
    initial_learning_rate = 1e-3  # or whatever you prefer
    lr_schedule = CosineDecayRestarts(
        initial_learning_rate=initial_learning_rate,
        first_decay_steps=10,     # number of steps before the first restart
        t_mul=2.0,                # restart cycle grows by this factor
        m_mul=1.0,                # multiplier for LR after each restart
        alpha=1e-6                # minimum learning rate value
    )

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    history = model.fit(X_train, y_train,
                        validation_data=(X_val, y_val),
                        epochs=epochs,
                        batch_size=batch_size,
                        callbacks=[early_stop],
                        verbose=1)

    # Plot loss
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.legend()
    plt.title("Training vs Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    # Predict
    y_pred_train = model.predict(X_train)
    y_pred_val = model.predict(X_val)
    y_pred_test = model.predict(X_test)

    # Evaluate
    sets = ['Train', 'Validation', 'Test']
    trues = [y_train, y_val, y_test]
    preds = [y_pred_train, y_pred_val, y_pred_test]

    print("Set        | Precision | Recall | F1 Score | AUC")
    print("-----------|-----------|--------|----------|------")
    for name, y_t, y_p in zip(sets, trues, preds):
        precision, recall, f1, auc = evaluate_metrics(y_t, y_p)
        print(f"{name:<10} | {precision:.3f}     | {recall:.3f}  | {f1:.3f}    | {auc:.3f}")
        model_results[base_model_fn] = {
            "Precision": round(precision, 3),
            "Recall": round(recall, 3),
            "F1 Score": round(f1, 3),
            "AUC": round(auc, 3) if auc is not None else None
        }

# %%
print("\n=== Running: RESNET50 ===")
model_results["RESNET50"] = {}
indices = np.arange(len(X_train))
np.random.seed(42)
np.random.shuffle(indices)
X_train_shuffled = X_train[indices]
y_train_shuffled = y_train[indices]
val_size = int(0.2 * len(X_train_shuffled))
X_val = X_train_shuffled[:val_size]
y_val = y_train_shuffled[:val_size]
X_train_split = X_train_shuffled[val_size:]
y_train_split = y_train_shuffled[val_size:]
run_transfer_learning_pipeline("resnet50", X_train_split, y_train_split, X_val, y_val, X_test, y_test)
# Out:
# === Running: RESNET50 ===
# Epoch 1/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 18s 81ms/step - accuracy: 0.5725 - loss: 5.6548 - val_accuracy: 0.7708 - val_loss: 3.5499
# Epoch 2/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 73ms/step - accuracy: 0.8456 - loss: 2.9672 - val_accuracy: 0.7905 - val_loss: 2.2532
# Epoch 3/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 73ms/step - accuracy: 0.8710 - loss: 1.7945 - val_accuracy: 0.7905 - val_loss: 1.6332
# Epoch 4/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 72ms/step - accuracy: 0.8849 - loss: 1.2378 - val_accuracy: 0.7984 - val_loss: 1.4151
# Epoch 5/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 72ms/step - accuracy: 0.8870 - loss: 1.0621 - val_accuracy: 0.7852 - val_loss: 1.3403
# Epoch 6/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 72ms/step - accuracy: 0.8844 - loss: 1.0305 - val_accuracy: 0.8050 - val_loss: 1.2960
# Epoch 7/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 72ms/step - accuracy: 0
100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 73ms/step - accuracy: 0.9301 - loss: 0.6900 - val_accuracy: 0.8274 - val_loss: 1.0558
# Epoch 40/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 73ms/step - accuracy: 0.9485 - loss: 0.6335 - val_accuracy: 0.8221 - val_loss: 0.9825
# Epoch 41/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 73ms/step - accuracy: 0.9322 - loss: 0.6283 - val_accuracy: 0.8327 - val_loss: 1.0058
# Epoch 42/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 73ms/step - accuracy: 0.9312 - loss: 0.6534 - val_accuracy: 0.8235 - val_loss: 1.0268
# Epoch 43/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 74ms/step - accuracy: 0.9399 - loss: 0.6559 - val_accuracy: 0.8182 - val_loss: 1.0623
# Epoch 44/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 74ms/step - accuracy: 0.9373 - loss: 0.6397 - val_accuracy: 0.8287 - val_loss: 1.0082
# Epoch 45/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 74ms/step - accuracy: 0.9424 - loss: 0.6086 - val_accuracy: 0.8274 - val_loss: 0.9821
# Epoch 46/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 74ms/step - accuracy: 0.9429 - loss: 0.6034 - val_accuracy: 0.8050 - val_loss: 1.0890
# Epoch 47/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 72ms/step - accuracy: 0.9153 - loss: 0.6902 - val_accuracy: 0.8050 - val_loss: 1.1148
# Epoch 48/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 72ms/step - accuracy: 0.9357 - loss: 0.6400 - val_accuracy: 0.8300 - val_loss: 0.9549
# Epoch 49/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 72ms/step - accuracy: 0.9301 - loss: 0.6223 - val_accuracy: 0.8103 - val_loss: 1.0576
# Epoch 50/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 73ms/step - accuracy: 0.9360 - loss: 0.6085 - val_accuracy: 0.8155 - val_loss: 1.0353
# Epoch 51/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 72ms/step - accuracy: 0.9346 - loss: 0.6344 - val_accuracy: 0.8208 - val_loss: 0.9896
# Epoch 52/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 72ms/step - accuracy: 0.9409 - loss: 0.5860 - val_accuracy: 0.8445 - val_loss: 0.9287
# Epoch 53/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 72ms/step - accuracy: 0.9454 - loss: 0.5713 - val_accuracy: 0.8261 - val_loss: 0.9968
# Epoch 54/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 72ms/step - accuracy: 0.9421 - loss: 0.5976 - val_accuracy: 0.8129 - val_loss: 1.0099
# Epoch 55/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 72ms/step - accuracy: 0.9232 - loss: 0.6271 - val_accuracy: 0.8327 - val_loss: 1.0281
# Epoch 56/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 72ms/step - accuracy: 0.9271 - loss: 0.6277 - val_accuracy: 0.8445 - val_loss: 0.9374
# Epoch 57/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 72ms/step - accuracy: 0.9499 - loss: 0.5762 - val_accuracy: 0.8472 - val_loss: 0.8943
# Epoch 58/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 72ms/step - accuracy: 0.9452 - loss: 0.5421 - val_accuracy: 0.8472 - val_loss: 0.9188
# Epoch 59/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 72ms/step - accuracy: 0.9420 - loss: 0.5466 - val_accuracy: 0.8063 - val_loss: 0.9992
# Epoch 60/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 72ms/step - accuracy: 0.9423 - loss: 0.5764 - val_accuracy: 0.8182 - val_loss: 1.0092
# Epoch 61/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 72ms/step - accuracy: 0.9433 - loss: 0.5585 - val_accuracy: 0.8221 - val_loss: 0.9441
# Epoch 62/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 14s 72ms/step - accuracy: 0.9384 - loss: 0.5793 - val_accuracy: 0.8287 - val_loss: 0.9444
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 12s 113ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step
# Set        | Precision | Recall | F1 Score | AUC
# -----------|-----------|--------|----------|------
# Train      | 0.988     | 0.987  | 0.987    | 1.000
# Validation | 0.854     | 0.852  | 0.851    | 0.986
# Test       | 0.814     | 0.763  | 0.779    | 0.971

# %%
print("\n=== Running: RESNET101 ===")
indices = np.arange(len(X_train))
np.random.seed(42)
np.random.shuffle(indices)
X_train_shuffled = X_train[indices]
y_train_shuffled = y_train[indices]
val_size = int(0.2 * len(X_train_shuffled))
X_val = X_train_shuffled[:val_size]
y_val = y_train_shuffled[:val_size]
X_train_split = X_train_shuffled[val_size:]
y_train_split = y_train_shuffled[val_size:]
run_transfer_learning_pipeline("resnet101", X_train_split, y_train_split, X_val, y_val, X_test, y_test)
# Out:
# === Running: RESNET101 ===
# Epoch 1/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━
100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.9043 - loss: 0.7715 - val_accuracy: 0.8235 - val_loss: 1.1308
# Epoch 30/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.9096 - loss: 0.7865 - val_accuracy: 0.8169 - val_loss: 1.1014
# Epoch 31/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.9271 - loss: 0.7205 - val_accuracy: 0.8458 - val_loss: 0.9775
# Epoch 32/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.9246 - loss: 0.7262 - val_accuracy: 0.8300 - val_loss: 1.0691
# Epoch 33/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.9258 - loss: 0.7299 - val_accuracy: 0.8314 - val_loss: 1.0278
# Epoch 34/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.9282 - loss: 0.7262 - val_accuracy: 0.8248 - val_loss: 1.0170
# Epoch 35/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.9290 - loss: 0.6977 - val_accuracy: 0.8208 - val_loss: 1.0363
# Epoch 36/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.9305 - loss: 0.6907 - val_accuracy: 0.8366 - val_loss: 0.9930
# Epoch 37/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.9347 - loss: 0.6608 - val_accuracy: 0.8261 - val_loss: 0.9991
# Epoch 38/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.9314 - loss: 0.6919 - val_accuracy: 0.7997 - val_loss: 1.0599
# Epoch 39/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.9230 - loss: 0.7121 - val_accuracy: 0.7984 - val_loss: 1.1070
# Epoch 40/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.9313 - loss: 0.6674 - val_accuracy: 0.8314 - val_loss: 0.9882
# Epoch 41/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.9272 - loss: 0.6670 - val_accuracy: 0.8221 - val_loss: 1.0212
# Epoch 42/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.9263 - loss: 0.6676 - val_accuracy: 0.8261 - val_loss: 1.0438
# Epoch 43/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.9392 - loss: 0.6609 - val_accuracy: 0.8169 - val_loss: 1.0180
# Epoch 44/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.9505 - loss: 0.6132 - val_accuracy: 0.8155 - val_loss: 1.0074
# Epoch 45/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.9362 - loss: 0.6343 - val_accuracy: 0.8261 - val_loss: 0.9997
# Epoch 46/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.9494 - loss: 0.6041 - val_accuracy: 0.8182 - val_loss: 0.9452
# Epoch 47/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.9350 - loss: 0.6175 - val_accuracy: 0.8327 - val_loss: 0.9743
# Epoch 48/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.9372 - loss: 0.6313 - val_accuracy: 0.8314 - val_loss: 0.9769
# Epoch 49/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.9431 - loss: 0.6082 - val_accuracy: 0.8090 - val_loss: 1.0490
# Epoch 50/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 118ms/step - accuracy: 0.9343 - loss: 0.6230 - val_accuracy: 0.8300 - val_loss: 0.9574
# Epoch 51/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.9381 - loss: 0.5896 - val_accuracy: 0.8195 - val_loss: 0.9999
# Epoch 52/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.9435 - loss: 0.5980 - val_accuracy: 0.8287 - val_loss: 0.9884
# Epoch 53/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.9384 - loss: 0.6183 - val_accuracy: 0.8261 - val_loss: 0.9651
# Epoch 54/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.9346 - loss: 0.5938 - val_accuracy: 0.8208 - val_loss: 0.9867
# Epoch 55/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - accuracy: 0.9488 - loss: 0.5655 - val_accuracy: 0.8208 - val_loss: 0.9577
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 21s 200ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 197ms/step
# Set        | Precision | Recall | F1 Score | AUC
# -----------|-----------|--------|----------|------
# Train      | 0.984     | 0.983  | 0.983    | 1.000
# Validation | 0.844     | 0.838  | 0.839    | 0.984
# Test       | 0.797     | 0.752  | 0.764    | 0.971

# %%
# === VGG16 ===
print("\n=== Running: VGG16 ===")
model_results["VGG16"] = {}
indices = np.arange(len(X_train))
np.random.seed(42)
np.random.shuffle(indices)
X_train_shuffled = X_train[indices]
y_train_shuffled = y_train[indices]
val_size = int(0.2 * len(X_train_shuffled))
X_val = X_train_shuffled[:val_size]
y_val = y_train_shuffled[:val_size]
X_train_split = X_train_shuffled[val_size:]
y_train_split = y_train_shuffled[val_size:]
run_transfer_learning_pipeline("vgg16", X_train_split, y_train_split, X_val, y_val, X_test, y_test)
# Out:
# === Running: VGG16 ===
# Epoch 1/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - accuracy: 0.4808 - loss: 4.5332 - val_accuracy: 0.7404 - val_loss: 2.7428
# Epoch 2/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.7674 - loss: 2.4037 - val_accuracy: 0.7378 - val_loss: 1.8367
# Epoch 3/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.7967 - loss: 1.5809 - val_accuracy: 0.7576 - val_loss: 1.3998
# Epoch 4/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.8354 - loss: 1.1605 - val_accuracy: 0.7905 - val_loss: 1.1509
# Epoch 5/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.8197 - loss: 0.9984 - val_accuracy: 0.7813 - val_loss: 1.0557
# Epoch 6/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.8342 - loss: 0.8836 - val_accuracy: 0.7813 - val_loss: 1.0173
# Epoch 7/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.8456 - loss: 0.8516 - val_accuracy: 0.8037 - val_loss: 0.9716
# Epoch 8/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.8391 - loss: 0.8561 - val_accuracy: 0.8037 - val_loss: 0.9748
# Epoch 9/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.8516 - loss: 0.8000 - val_accuracy: 0.8037 - val_loss: 1.0092
# Epoch 10/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.8542 - loss: 0.8054 - val_accuracy: 0.8037 - val_loss: 0.9773
# Epoch 11/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.8597 - loss: 0.7752 - val_accuracy: 0.8248 - val_loss: 0.9042
# Epoch 12/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.8660 - loss: 0.7729 - val_accuracy: 0.7905 - val_loss: 0.9807
# Epoch 13/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.8610 - loss: 0.7972 - val_accuracy: 0.8037 - val_loss: 0.9870
# Epoch 14/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.8793 - loss: 0.7557 - val_accuracy: 0.7918 - val_loss: 0.9597
# Epoch 15/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.8736 - loss: 0.7491 - val_accuracy: 0.8195 - val_loss: 0.9049
# Epoch 16/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.8832 - loss: 0.7319 - val_accuracy: 0.7866 - val_loss: 0.9812
# Epoch 17/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.8846 - loss: 0.7140 - val_accuracy: 0.8050 - val_loss: 0.9465
# Epoch 18/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.8794 - loss: 0.7311 - val_accuracy: 0.8142 - val_loss: 0.9582
# Epoch 19/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.8747 - loss: 0.7459 - val_accuracy: 0.8142 - val_loss: 0.9845
# Epoch 20/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.8913 - loss: 0.7327 - val_accuracy: 0.8261 - val_loss: 0.9204
# Epoch 21/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.8823 - loss: 0.7232 - val_accuracy: 0.8116 - val_loss: 0.9645
# Epoch 22/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.8889 - loss: 0.7304 - val_accuracy: 0.7984 - val_loss: 1.0108
# Epoch 23/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.8796 - loss: 0.7387 - val_accuracy: 0.8142 - val_loss: 0.9302
# Epoch 24/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.8953 - loss: 0.6990 - val_accuracy: 0.8248 - val_loss: 0.9329
# Epoch 25/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.8981 - loss: 0.6901 - val_accuracy: 0.8129 - val_loss: 0.9360
# Epoch 26/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.8885 - loss: 0.7028 - val_accuracy: 0.8182 - val_loss: 0.9633
# Epoch 27/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.
100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.9269 - loss: 0.5844 - val_accuracy: 0.8393 - val_loss: 0.8645
# Epoch 60/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.9120 - loss: 0.5924 - val_accuracy: 0.8142 - val_loss: 0.9257
# Epoch 61/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.9203 - loss: 0.5934 - val_accuracy: 0.8169 - val_loss: 0.8812
# Epoch 62/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.9357 - loss: 0.5502 - val_accuracy: 0.8011 - val_loss: 0.9234
# Epoch 63/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.9269 - loss: 0.5778 - val_accuracy: 0.8235 - val_loss: 0.8930
# Epoch 64/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.9212 - loss: 0.5753 - val_accuracy: 0.8221 - val_loss: 0.8633
# Epoch 65/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.9272 - loss: 0.5493 - val_accuracy: 0.8208 - val_loss: 0.9007
# Epoch 66/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.9180 - loss: 0.5701 - val_accuracy: 0.8169 - val_loss: 0.8922
# Epoch 67/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.9209 - loss: 0.5681 - val_accuracy: 0.8208 - val_loss: 0.9169
# Epoch 68/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.9075 - loss: 0.5990 - val_accuracy: 0.8261 - val_loss: 0.8860
# Epoch 69/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.9225 - loss: 0.5817 - val_accuracy: 0.8129 - val_loss: 0.8919
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 175ms/step
# Set        | Precision | Recall | F1 Score | AUC
# -----------|-----------|--------|----------|------
# Train      | 0.984     | 0.983  | 0.983    | 1.000
# Validation | 0.828     | 0.827  | 0.825    | 0.983
# Test       | 0.761     | 0.728  | 0.739    | 0.970

# %%
# === EFFICIENTNETB0 ===
print("\n=== Running: EFFICIENTNETB0 ===")
model_results["EFFICIENTNETB0"] = {}
indices = np.arange(len(X_train))
np.random.seed(42)
np.random.shuffle(indices)
X_train_shuffled = X_train[indices]
y_train_shuffled = y_train[indices]
val_size = int(0.2 * len(X_train_shuffled))
X_val = X_train_shuffled[:val_size]
y_val = y_train_shuffled[:val_size]
X_train_split = X_train_shuffled[val_size:]
y_train_split = y_train_shuffled[val_size:]
run_transfer_learning_pipeline("efficientnetb0", X_train_split, y_train_split, X_val, y_val, X_test, y_test)
# Out:
# === Running: EFFICIENTNETB0 ===
# Epoch 1/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - accuracy: 0.5805 - loss: 5.1165 - val_accuracy: 0.8024 - val_loss: 3.0738
# Epoch 2/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.8381 - loss: 2.5892 - val_accuracy: 0.8142 - val_loss: 1.9033
# Epoch 3/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.8531 - loss: 1.6040 - val_accuracy: 0.8063 - val_loss: 1.3576
# Epoch 4/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.8975 - loss: 1.0719 - val_accuracy: 0.8314 - val_loss: 1.0986
# Epoch 5/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.8915 - loss: 0.8871 - val_accuracy: 0.8195 - val_loss: 1.0597
# Epoch 6/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.8831 - loss: 0.8824 - val_accuracy: 0.8195 - val_loss: 1.1345
# Epoch 7/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.8862 - loss: 0.8760 - val_accuracy: 0.8090 - val_loss: 1.0891
# Epoch 8/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.8863 - loss: 0.8788 - val_accuracy: 0.8287 - val_loss: 1.0449
# Epoch 9/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.8937 - loss: 0.8176 - val_accuracy: 0.8090 - val_loss: 1.0777
# Epoch 10/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.8881 - loss: 0.8324 - val_accuracy: 0.8248 - val_loss: 1.0851
# Epoch 11/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0
100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.9363 - loss: 0.5931 - val_accuracy: 0.8393 - val_loss: 0.9269
# Epoch 44/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.9387 - loss: 0.6003 - val_accuracy: 0.8538 - val_loss: 0.8414
# Epoch 45/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.9357 - loss: 0.5896 - val_accuracy: 0.8445 - val_loss: 0.8603
# Epoch 46/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.9351 - loss: 0.5714 - val_accuracy: 0.8524 - val_loss: 0.8153
# Epoch 47/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.9212 - loss: 0.6182 - val_accuracy: 0.8300 - val_loss: 0.9225
# Epoch 48/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.9273 - loss: 0.6412 - val_accuracy: 0.8498 - val_loss: 0.8730
# Epoch 49/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.9247 - loss: 0.6129 - val_accuracy: 0.8498 - val_loss: 0.8401
# Epoch 50/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 49ms/step - accuracy: 0.9315 - loss: 0.5809 - val_accuracy: 0.8551 - val_loss: 0.8561
# Epoch 51/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.9287 - loss: 0.6036 - val_accuracy: 0.8379 - val_loss: 0.8690
# Epoch 52/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 49ms/step - accuracy: 0.9353 - loss: 0.5692 - val_accuracy: 0.8445 - val_loss: 0.8303
# Epoch 53/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.9435 - loss: 0.5407 - val_accuracy: 0.8472 - val_loss: 0.8611
# Epoch 54/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.9339 - loss: 0.5807 - val_accuracy: 0.8432 - val_loss: 0.8391
# Epoch 55/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 49ms/step - accuracy: 0.9372 - loss: 0.5728 - val_accuracy: 0.8419 - val_loss: 0.8137
# Epoch 56/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 49ms/step - accuracy: 0.9380 - loss: 0.5696 - val_accuracy: 0.8590 - val_loss: 0.7879
# Epoch 57/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.9421 - loss: 0.5137 - val_accuracy: 0.8393 - val_loss: 0.8535
# Epoch 58/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 49ms/step - accuracy: 0.9342 - loss: 0.5531 - val_accuracy: 0.8551 - val_loss: 0.7868
# Epoch 59/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.9442 - loss: 0.5339 - val_accuracy: 0.8327 - val_loss: 0.8714
# Epoch 60/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.9324 - loss: 0.5587 - val_accuracy: 0.8538 - val_loss: 0.8285
# Epoch 61/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.9359 - loss: 0.5600 - val_accuracy: 0.8393 - val_loss: 0.8112
# Epoch 62/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.9304 - loss: 0.5613 - val_accuracy: 0.8524 - val_loss: 0.8320
# Epoch 63/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.9306 - loss: 0.5690 - val_accuracy: 0.8538 - val_loss: 0.8411
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step
# Set        | Precision | Recall | F1 Score | AUC
# -----------|-----------|--------|----------|------
# Train      | 0.987     | 0.987  | 0.987    | 1.000
# Validation | 0.855     | 0.851  | 0.852    | 0.989
# Test       | 0.802     | 0.769  | 0.776    | 0.978

# %%
model_results
# Out:
# {'RESNET50': {},
#  'resnet50': {'Precision': 0.814,
#   'Recall': 0.763,
#   'F1 Score': 0.779,
#   'AUC': 0.971},
#  'resnet101': {'Precision': 0.797,
#   'Recall': 0.752,
#   'F1 Score': 0.764,
#   'AUC': 0.971},
#  'VGG16': {},
#  'vgg16': {'Precision': 0.761,
#   'Recall': 0.728,
#   'F1 Score': 0.739,
#   'AUC': 0.97},
#  'EFFICIENTNETB0': {},
#  'efficientnetb0': {'Precision': 0.802,
#   'Recall': 0.769,
#   'F1 Score': 0.776,
#   'AUC': 0.978}}
